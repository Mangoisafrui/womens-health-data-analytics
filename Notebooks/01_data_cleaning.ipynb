# %%
# Import libraries
import pandas as pd
import numpy as np

# Tell pandas to show all columns
pd.set_option('display.max_columns', None)

print("Libraries loaded successfully!")
# Out:
# Libraries loaded successfully!

# %%
import pandas as pd
import numpy as np

print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("All good!")
# Out:
# pandas version: 3.0.3
# numpy version: 2.3.3
# All good!

# %%
# ============================================
# WOMEN'S MENTAL HEALTH PROJECT
# Notebook 1: Data Loading & Cleaning
# Author: Christelle Denny
# Date: June 2026
# ============================================

import pandas as pd
import numpy as np

print("Libraries loaded successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Libraries loaded successfully!
# Pandas version: 3.0.3
# NumPy version: 2.3.3

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

# GBD Prevalence
gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')

# GBD DALYs
gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')

# World Bank Country Classifications
world_bank = pd.read_excel(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_Country_Classifications.xlsx')

# UNDP Gender Inequality Index
gii = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GII_UNDP\UNDP_GII_All_Countries.csv')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\WHO_Atlas\WHO_Psychiatrists_Per_100k.csv')

# World Bank GDP per Capita
gdp = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_GDP_Per_Capita.csv', skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 6
#       1 # ============================================
#       2 # STEP 1: LOAD ALL DATASETS
#       3 # ============================================
#       4
#       5 # GBD Prevalence
# ----> 6 gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')
#       8 # GBD DALYs
#       9 gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')
#
# ...

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

# GBD Prevalence
gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')

# GBD DALYs
gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')

# World Bank Country Classifications
world_bank = pd.read_excel(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_Country_Classifications.xlsx')

# UNDP Gender Inequality Index
gii = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GII_UNDP\UNDP_GII_All_Countries.csv')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\WHO_Atlas\WHO_Psychiatrists_Per_100k.csv')

# World Bank GDP per Capita
gdp = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_GDP_Per_Capita.csv', skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 6
#       1 # ============================================
#       2 # STEP 1: LOAD ALL DATASETS
#       3 # ============================================
#       4
#       5 # GBD Prevalence
# ----> 6 gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')
#       8 # GBD DALYs
#       9 gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')
#
# ...

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

# GBD Prevalence
gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')

# GBD DALYs
gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')

# World Bank Country Classifications
world_bank = pd.read_excel(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_Country_Classifications.xlsx')

# UNDP Gender Inequality Index
gii = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GII_UNDP\UNDP_GII_All_Countries.csv')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\WHO_Atlas\WHO_Psychiatrists_Per_100k.csv')

# World Bank GDP per Capita
gdp = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_GDP_Per_Capita.csv', skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       1 # ============================================
#       2 # STEP 1: LOAD ALL DATASETS
#       3 # ============================================
#       4
#       5 # GBD Prevalence
# ----> 6 gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')
#       8 # GBD DALYs
#       9 gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')
#
# ...

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

# GBD Prevalence
gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')

# GBD DALYs
gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')

# World Bank Country Classifications
world_bank = pd.read_excel(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_Country_Classifications.xlsx')

# UNDP Gender Inequality Index
gii = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GII_UNDP\UNDP_GII_All_Countries.csv')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\WHO_Atlas\WHO_Psychiatrists_Per_100k.csv')

# World Bank GDP per Capita
gdp = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\World_Bank\World_Bank_GDP_Per_Capita.csv', skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       1 # ============================================
#       2 # STEP 1: LOAD ALL DATASETS
#       3 # ============================================
#       4
#       5 # GBD Prevalence
# ----> 6 gbd_prev = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_Prevalence_Women_1549.csv')
#       8 # GBD DALYs
#       9 gbd_daly = pd.read_csv(r'C:\Users\Dell\OneDrive\Desktop\Women\'s Mental Health\Raw Data\GBD_2021\GBD_2021_DALYs_Women_1549.csv')
#
# ...

# %%
import os

# Check what's on your Desktop
desktop = r'C:\Users\Dell\OneDrive\Desktop'
for item in os.listdir(desktop):
    print(item)
# Out:
# 1894604_1_Gold Loan-Confirmation from borrowers regarding release of Gold ornaments to third party_signed.pdf
# 2358407_1_Third party release letter_signed.pdf
# 4DcVDZi.jpg
# art
# articles read.pdf
# Beauceron   NSCC Security Awareness Training (Christelle) (1).lnk
# Christelle - Chrome.lnk
# Cisco Packet Tracer.lnk
# class_schedule.png
# desktop.ini
# Downloads - Shortcut.lnk
# Firefox.exe
# FMHY - freemediaheckyeah.lnk
# GitHub Desktop.lnk
# Glint - Real-time Prediction Market Intelligence (Christelle).lnk
# Grammarly.lnk
# Heightened-interoception-in-adults-with-fibromyalgia.pdf
# nscc
# pdfs
# research
# research.pdf
# Resume.pdf
# wallpaper
# WhatsApp Installer.exe
# Women's Mental Health
# Work Experience - Nova Scotia Community College - Home (Christelle).lnk
# wp9228873.jpg
# ~$ntact details.docx

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index
gii = pd.read_csv(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index
gii = pd.read_csv(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv", encoding='latin1')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 17
#      14 world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")
#      16 # UNDP Gender Inequality Index
# ---> 17 gii = pd.read_csv(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")
#      19 # WHO Psychiatrists per 100k
#      20 psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")
#
# ...

# %%
# Install chardet to detect encoding
import subprocess
subprocess.run(['pip', 'install', 'chardet'])

import chardet

with open(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv", 'rb') as f:
    result = chardet.detect(f.read(100000))
    
print("Detected encoding:", result['encoding'])
print("Confidence:", result['confidence'])
# Out:
# Detected encoding: None
# Confidence: 1.0

# %%
# Check what the file actually looks like
with open(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv", 'rb') as f:
    raw = f.read(200)
    print("Raw bytes:", raw)
    print("\nFile size:", len(raw), "bytes")
# Out:
# Raw bytes: b'PK\x03\x04\x14\x00\x06\x00\x08\x00\x00\x00!\x00\xdd+\x8bXl\x01\x00\x00\x10\x05\x00\x00\x13\x00\x08\x02[Content_Types].xml \xa2\x04\x02('
#
# File size: 200 bytes

# %%
# UNDP Gender Inequality Index
gii = pd.read_excel(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index
gii = pd.read_excel(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index
gii = pd.read_csv(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv", encoding='latin1')

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ✓ GBD Prevalence: (8976, 11)
# ✓ GBD DALYs: (8976, 11)
# ✓ World Bank Classifications: (267, 5)
# ✓ UNDP GII: (4600, 12)
# ✓ WHO Psychiatrists: (143, 4)
# ✓ GDP per Capita: (266, 71)
#
# All datasets loaded successfully!
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 49
#      46 world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")
#      48 # UNDP Gender Inequality Index
# ---> 49 gii = pd.read_csv(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv", encoding='latin1')
#      51 # WHO Psychiatrists per 100k
#      52 psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")
#
# ...

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index — Excel format despite .csv extension
gii = pd.read_excel(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ✓ GBD Prevalence: (8976, 11)
# ✓ GBD DALYs: (8976, 11)
# ✓ World Bank Classifications: (267, 5)
# ✓ UNDP GII: (4600, 12)
# ✓ WHO Psychiatrists: (143, 4)
# ✓ GDP per Capita: (266, 71)
#
# All datasets loaded successfully!

# %%
# ============================================
# STEP 1: LOAD ALL DATASETS
# ============================================

base = "C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Raw Data"

# GBD Prevalence
gbd_prev = pd.read_csv(f"{base}/GBD_2021/GBD_2021_Prevalence_Women_1549.csv")

# GBD DALYs
gbd_daly = pd.read_csv(f"{base}/GBD_2021/GBD_2021_DALYs_Women_1549.csv")

# World Bank Country Classifications
world_bank = pd.read_excel(f"{base}/World_Bank/World_Bank_Country_Classifications.xlsx")

# UNDP Gender Inequality Index — Excel format despite .csv extension
gii = pd.read_excel(f"{base}/GII_UNDP/UNDP_GII_All_Countries.csv")

# WHO Psychiatrists per 100k
psychiatrists = pd.read_csv(f"{base}/WHO_Atlas/WHO_Psychiatrists_Per_100k.csv")

# World Bank GDP per Capita
gdp = pd.read_csv(f"{base}/World_Bank/World_Bank_GDP_Per_Capita.csv", skiprows=4)

# ── Confirm all loaded ──
print("✓ GBD Prevalence:", gbd_prev.shape)
print("✓ GBD DALYs:", gbd_daly.shape)
print("✓ World Bank Classifications:", world_bank.shape)
print("✓ UNDP GII:", gii.shape)
print("✓ WHO Psychiatrists:", psychiatrists.shape)
print("✓ GDP per Capita:", gdp.shape)
print("\nAll datasets loaded successfully!")
# Out:
# ✓ GBD Prevalence: (8976, 11)
# ✓ GBD DALYs: (8976, 11)
# ✓ World Bank Classifications: (267, 5)
# ✓ UNDP GII: (4600, 12)
# ✓ WHO Psychiatrists: (143, 4)
# ✓ GDP per Capita: (266, 71)
#
# All datasets loaded successfully!

# %%
# ============================================
# STEP 2: EXPLORE EACH DATASET
# ============================================

datasets = {
    "GBD Prevalence": gbd_prev,
    "GBD DALYs": gbd_daly,
    "World Bank": world_bank,
    "UNDP GII": gii,
    "WHO Psychiatrists": psychiatrists,
    "GDP per Capita": gdp
}

for name, df in datasets.items():
    print(f"\n{'='*50}")
    print(f"DATASET: {name}")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(f"Missing values:\n{df.isnull().sum()}")
    print(f"\nFirst row:\n{df.iloc[0]}")
# Out:
# ...
# DATASET: GBD Prevalence
# Shape: (8976, 11)
# Columns: ['population_group', 'measure', 'location', 'sex', 'age', 'cause', 'metric', 'year', 'val', 'upper', 'lower']
# Missing values:
# population_group    0
# measure             0
# location            0
# sex                 0
# age                 0
# cause               0
# metric              0
# year                0
# val                 0
# upper               0
# lower               0
# dtype: int64
#
# First row:
# population_group          All Population
# measure                       Prevalence
# location                        Suriname
# sex                               Female
# age                          15-49 years
# cause               Depressive disorders
# metric                              Rate
# year                                2000
# val                          5075.188955
# upper                        6150.285294
# lower                        4136.924963
# Name: 0, dtype: object
#
# ...
# DATASET: GBD DALYs
# ...

# %%
# ============================================
# STEP 3: LOOK INSIDE EACH DATASET
# ============================================

# GBD Prevalence — first 3 rows
print("=== GBD PREVALENCE ===")
print(gbd_prev.head(3))

print("\n=== WORLD BANK CLASSIFICATIONS ===")
print(world_bank.head(3))
print("Columns:", list(world_bank.columns))

print("\n=== UNDP GII ===")
print(gii.head(3))
print("Columns:", list(gii.columns))

print("\n=== WHO PSYCHIATRISTS ===")
print(psychiatrists.head(3))

print("\n=== GDP PER CAPITA ===")
print(gdp.head(3))
print("First 10 columns:", list(gdp.columns[:10]))
# Out:
# === GBD PREVALENCE ===
#   population_group     measure         location     sex          age  \
# 0   All Population  Prevalence         Suriname  Female  15-49 years
# 1   All Population  Prevalence         Suriname  Female  15-49 years
# 2   All Population  Prevalence  Solomon Islands  Female  15-49 years
#
#                   cause metric  year          val        upper        lower
# 0  Depressive disorders   Rate  2000  5075.188955  6150.285294  4136.924963
# 1     Anxiety disorders   Rate  2000  6919.581675  8816.120535  5371.200218
# 2  Depressive disorders   Rate  2001  2962.021924  4108.491562  2118.977628
#
# === WORLD BANK CLASSIFICATIONS ===
#        Economy Code                      Region         Income group  \
# 0  Afghanistan  AFG                  South Asia           Low income
# 1      Albania  ALB       Europe & Central Asia  Upper middle income
# 2      Algeria  DZA  Middle East & North Africa  Upper middle income
#
#   Lending category
# 0              IDA
# ...

# %%
# ============================================
# STEP 4: CHECK COUNTRY NAME FORMATS
# ============================================

print("GBD unique countries:", gbd_prev['location'].nunique())
print("Sample GBD countries:", list(gbd_prev['location'].unique()[:5]))

print("\nWorld Bank unique countries:", world_bank['Economy'].nunique())
print("Sample World Bank countries:", list(world_bank['Economy'].unique()[:5]))

print("\nGDP unique countries:", gdp['Country Name'].nunique())
print("Sample GDP countries:", list(gdp['Country Name'].unique()[:5]))

print("\nWHO Psychiatrists columns:", list(psychiatrists.columns))
print("Sample WHO countries:", list(psychiatrists.iloc[:5, 0]))
# Out:
# GBD unique countries: 204
# Sample GBD countries: ['Suriname', 'Solomon Islands', 'Czechia', 'Guatemala', 'Algeria']
#
# World Bank unique countries: 266
# Sample World Bank countries: ['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra']
#
# GDP unique countries: 266
# Sample GDP countries: ['Aruba', 'Africa Eastern and Southern', 'Afghanistan', 'Africa Western and Central', 'Angola']
#
# WHO Psychiatrists columns: ['Entity', 'Code', 'Year', 'Total number of psychiatrists per 100,000 population']
# Sample WHO countries: ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Antigua and Barbuda']

# %%
# ============================================
# STEP 5: CLEAN COLUMN NAMES
# ============================================

# Rename country columns to standard name
gbd_prev = gbd_prev.rename(columns={'location': 'country'})
gbd_daly = gbd_daly.rename(columns={'location': 'country'})
world_bank = world_bank.rename(columns={'Economy': 'country'})
gdp = gdp.rename(columns={'Country Name': 'country'})
psychiatrists = psychiatrists.rename(columns={
    'Entity': 'country',
    'Code': 'country_code',
    'Year': 'year',
    'Total number of psychiatrists per 100,000 population': 'psychiatrists_per_100k'
})

# Confirm
print("✓ GBD Prevalence columns:", list(gbd_prev.columns))
print("✓ World Bank columns:", list(world_bank.columns))
print("✓ GDP columns:", list(gdp.columns[:5]))
print("✓ WHO columns:", list(psychiatrists.columns))
print("\nColumn names standardized!")
# Out:
# ✓ GBD Prevalence columns: ['population_group', 'measure', 'country', 'sex', 'age', 'cause', 'metric', 'year', 'val', 'upper', 'lower']
# ✓ World Bank columns: ['country', 'Code', 'Region', 'Income group', 'Lending category']
# ✓ GDP columns: ['country', 'Country Code', 'Indicator Name', 'Indicator Code', '1960']
# ✓ WHO columns: ['country', 'country_code', 'year', 'psychiatrists_per_100k']
#
# Column names standardized!

# %%
# ============================================
# STEP 6: CLEAN GBD DATASETS
# ============================================

# Keep only columns we need
gbd_prev_clean = gbd_prev[['country', 'cause', 'year', 'val']].copy()
gbd_daly_clean = gbd_daly[['country', 'cause', 'year', 'val']].copy()

# Rename val column to be descriptive
gbd_prev_clean = gbd_prev_clean.rename(columns={'val': 'prevalence_rate'})
gbd_daly_clean = gbd_daly_clean.rename(columns={'val': 'daly_rate'})

# Separate depression and anxiety
prev_depression = gbd_prev_clean[gbd_prev_clean['cause'] == 'Depressive disorders'].copy()
prev_anxiety = gbd_prev_clean[gbd_prev_clean['cause'] == 'Anxiety disorders'].copy()

daly_depression = gbd_daly_clean[gbd_daly_clean['cause'] == 'Depressive disorders'].copy()
daly_anxiety = gbd_daly_clean[gbd_daly_clean['cause'] == 'Anxiety disorders'].copy()

# Confirm
print("Depression Prevalence:", prev_depression.shape)
print("Anxiety Prevalence:", prev_anxiety.shape)
print("Depression DALYs:", daly_depression.shape)
print("Anxiety DALYs:", daly_anxiety.shape)
print("\nSample depression data:")
print(prev_depression.head(3))
# Out:
# Depression Prevalence: (4488, 4)
# Anxiety Prevalence: (4488, 4)
# Depression DALYs: (4488, 4)
# Anxiety DALYs: (4488, 4)
#
# Sample depression data:
#            country                 cause  year  prevalence_rate
# 0         Suriname  Depressive disorders  2000      5075.188955
# 2  Solomon Islands  Depressive disorders  2001      2962.021924
# 5        Guatemala  Depressive disorders  2000      5421.266100

# %%
# ============================================
# STEP 7: CLEAN GDP DATASET
# ============================================

# Drop unnecessary columns
gdp_clean = gdp[['country', 'Country Code', '2000', '2005', '2010', 
                  '2015', '2019', '2020', '2021']].copy()

# Remove regional aggregates — keep only real countries
# Real countries have a 3-letter code
gdp_clean = gdp_clean[gdp_clean['Country Code'].str.len() == 3]

# Rename country code column
gdp_clean = gdp_clean.rename(columns={'Country Code': 'country_code'})

# Check result
print("GDP clean shape:", gdp_clean.shape)
print("Missing values:\n", gdp_clean.isnull().sum())
print("\nSample:")
print(gdp_clean.head(3))
# Out:
# GDP clean shape: (266, 9)
# Missing values:
#  country          0
# country_code     0
# 2000            14
# 2005             9
# 2010             5
# 2015             6
# 2019             7
# 2020             8
# 2021             8
# dtype: int64
#
# Sample:
#                        country country_code          2000          2005  \
# 0                        Aruba          ABW  20681.023027  24171.837133
# 1  Africa Eastern and Southern          AFE    706.727261   1126.297323
# 2                  Afghanistan          AFG    174.930991    254.184249
#
#            2010          2015          2019          2020          2021
# 0  24093.140151  27458.220154  30645.890602  22759.807175  26749.329609
# 1   1628.905248   1498.875240   1507.085600   1351.591669   1562.416175
# 2    560.621505    565.569730    496.602504    510.787063    356.496214

# %%
# ============================================
# STEP 8: CLEAN GDP FURTHER
# ============================================

# Remove regional aggregates using World Bank country list
# Keep only countries that exist in our World Bank classifications
valid_countries = world_bank['country'].tolist()
gdp_clean = gdp_clean[gdp_clean['country'].isin(valid_countries)]

print("GDP after removing aggregates:", gdp_clean.shape)
print("Missing values:\n", gdp_clean.isnull().sum())
print("\nSample:")
print(gdp_clean.head(3))
# Out:
# GDP after removing aggregates: (251, 9)
# Missing values:
#  country          0
# country_code     0
# 2000            13
# 2005             8
# 2010             4
# 2015             5
# 2019             6
# 2020             7
# 2021             7
# dtype: int64
#
# Sample:
#                        country country_code          2000          2005  \
# 0                        Aruba          ABW  20681.023027  24171.837133
# 1  Africa Eastern and Southern          AFE    706.727261   1126.297323
# 2                  Afghanistan          AFG    174.930991    254.184249
#
#            2010          2015          2019          2020          2021
# 0  24093.140151  27458.220154  30645.890602  22759.807175  26749.329609
# 1   1628.905248   1498.875240   1507.085600   1351.591669   1562.416175
# 2    560.621505    565.569730    496.602504    510.787063    356.496214

# %%
# ============================================
# STEP 9: REMOVE REMAINING AGGREGATES
# ============================================

# Check what's still in there that shouldn't be
# Regional aggregates usually contain words like these
remove_keywords = [
    'Africa', 'Asia', 'Europe', 'America', 'Caribbean',
    'Pacific', 'OECD', 'World', 'income', 'dividend',
    'Middle East', 'Central', 'Eastern', 'Western',
    'Northern', 'Southern', 'Latin', 'Sub-Saharan',
    'fragile', 'blend', 'IDA', 'IBRD', 'Euro'
]

# Build a filter — remove rows where country name contains any keyword
pattern = '|'.join(remove_keywords)
gdp_clean = gdp_clean[~gdp_clean['country'].str.contains(pattern, case=False, na=False)]

print("GDP after removing all aggregates:", gdp_clean.shape)
print("\nSample countries:")
print(gdp_clean['country'].head(10).tolist())

# Fill missing GDP values with median
gdp_clean = gdp_clean.fillna(gdp_clean.median(numeric_only=True))
print("\nMissing values after fill:")
print(gdp_clean.isnull().sum())
# Out:
# GDP after removing all aggregates: (209, 9)
#
# Sample countries:
# ['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'United Arab Emirates', 'Argentina', 'Armenia', 'Antigua and Barbuda', 'Australia']
#
# Missing values after fill:
# country         0
# country_code    0
# 2000            0
# 2005            0
# 2010            0
# 2015            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
# ============================================
# STEP 10: CLEAN WHO PSYCHIATRISTS DATASET
# ============================================

# Check what years are available
print("Years available:", sorted(psychiatrists['year'].unique()))
print("Countries:", psychiatrists['country'].nunique())
print("\nSample:")
print(psychiatrists.head(5))
# Out:
# Years available: [np.int64(2015), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020)]
# Countries: 143
#
# Sample:
#                country country_code  year  psychiatrists_per_100k
# 0          Afghanistan          AFG  2019                       0
# 1              Albania          ALB  2019                       2
# 2              Algeria          DZA  2019                       2
# 3              Andorra          AND  2019                      10
# 4  Antigua and Barbuda          ATG  2019                       1

# %%
# ============================================
# STEP 11: CLEAN WHO PSYCHIATRISTS DATASET
# ============================================

# Keep only 2019 data — most complete year
psychiatrists_clean = psychiatrists[psychiatrists['year'] == 2019].copy()

# Drop year and country_code columns — not needed for merge
psychiatrists_clean = psychiatrists_clean[['country', 'psychiatrists_per_100k']]

# Check result
print("Psychiatrists clean shape:", psychiatrists_clean.shape)
print("Missing values:\n", psychiatrists_clean.isnull().sum())
print("\nSample:")
print(psychiatrists_clean.head(5))

# Check range of values
print("\nPsychiatrists per 100k statistics:")
print(psychiatrists_clean['psychiatrists_per_100k'].describe())
# Out:
# Psychiatrists clean shape: (96, 2)
# Missing values:
#  country                   0
# psychiatrists_per_100k    0
# dtype: int64
#
# Sample:
#                country  psychiatrists_per_100k
# 0          Afghanistan                       0
# 1              Albania                       2
# 2              Algeria                       2
# 3              Andorra                      10
# 4  Antigua and Barbuda                       1
#
# Psychiatrists per 100k statistics:
# count    96.000000
# mean      3.197917
# std       4.727567
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       3.000000
# max      20.000000
# Name: psychiatrists_per_100k, dtype: float64

# %%
# ============================================
# STEP 12: EXPLORE GII DATASET
# ============================================

print("GII columns:", list(gii.columns))
print("\nGII shape:", gii.shape)
print("\nSample:")
print(gii.head(3))
print("\nUnique indicators:")
print(gii['indicator'].unique() if 'indicator' in gii.columns else "No indicator column")
# Out:
# GII columns: ['countryIsoCode', 'country', 'indexCode', 'index', 'dimension', 'indicatorCode', 'indicator', 'year', 'yearStr', 'actualValue', 'value', 'note']
#
# GII shape: (4600, 12)
#
# Sample:
#   countryIsoCode      country indexCode                    index  dimension  \
# 0            AFG  Afghanistan       GII  Gender Inequality Index        NaN
# 1            AFG  Afghanistan       GII  Gender Inequality Index        NaN
# 2            AFG  Afghanistan       GII  Gender Inequality Index        NaN
#
#   indicatorCode                        indicator  year  yearStr  actualValue  \
# 0           gii  Gender Inequality Index (value)  2008     2008        0.690
# 1           gii  Gender Inequality Index (value)  2009     2009        0.696
# 2           gii  Gender Inequality Index (value)  2010     2010        0.704
#
#    value  note
# 0  0.690   NaN
# 1  0.696   NaN
# 2  0.704   NaN
#
# Unique indicators:
# <StringArray>
# ['Gender Inequality Index (value)']
# ...

# %%
# ============================================
# STEP 12: EXPLORE GII DATASET
# ============================================

print("GII columns:", list(gii.columns))
print("\nGII shape:", gii.shape)
print("\nSample:")
print(gii.head(3))
# Out:
# GII columns: ['countryIsoCode', 'country', 'indexCode', 'index', 'dimension', 'indicatorCode', 'indicator', 'year', 'yearStr', 'actualValue', 'value', 'note']
#
# GII shape: (4600, 12)
#
# Sample:
#   countryIsoCode      country indexCode                    index  dimension  \
# 0            AFG  Afghanistan       GII  Gender Inequality Index        NaN
# 1            AFG  Afghanistan       GII  Gender Inequality Index        NaN
# 2            AFG  Afghanistan       GII  Gender Inequality Index        NaN
#
#   indicatorCode                        indicator  year  yearStr  actualValue  \
# 0           gii  Gender Inequality Index (value)  2008     2008        0.690
# 1           gii  Gender Inequality Index (value)  2009     2009        0.696
# 2           gii  Gender Inequality Index (value)  2010     2010        0.704
#
#    value  note
# 0  0.690   NaN
# 1  0.696   NaN
# 2  0.704   NaN

# %%
# ============================================
# STEP 13: CLEAN GII DATASET
# ============================================

# Keep only GII value rows
gii_clean = gii[gii['indicatorCode'] == 'gii'].copy()

# Keep only columns we need
gii_clean = gii_clean[['country', 'year', 'value']]

# Rename value column
gii_clean = gii_clean.rename(columns={'value': 'gii_score'})

# Keep only years 2000-2021
gii_clean = gii_clean[(gii_clean['year'] >= 2000) & (gii_clean['year'] <= 2021)]

print("GII clean shape:", gii_clean.shape)
print("Years covered:", sorted(gii_clean['year'].unique()))
print("Missing values:\n", gii_clean.isnull().sum())
print("\nSample:")
print(gii_clean.head(5))
# Out:
# GII clean shape: (3322, 3)
# Years covered: [np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021)]
# Missing values:
#  country      0
# year         0
# gii_score    0
# dtype: int64
#
# Sample:
#        country  year  gii_score
# 0  Afghanistan  2008      0.690
# 1  Afghanistan  2009      0.696
# 2  Afghanistan  2010      0.704
# 3  Afghanistan  2011      0.716
# 4  Afghanistan  2012      0.731

# %%
# ============================================
# STEP 14: RESHAPE GDP TO LONG FORMAT
# ============================================

gdp_long = gdp_clean.melt(
    id_vars=['country', 'country_code'],
    var_name='year',
    value_name='gdp_per_capita'
)

gdp_long['year'] = gdp_long['year'].astype(int)

print("GDP long shape:", gdp_long.shape)
print("\nSample:")
print(gdp_long.head(6))
# Out:
# GDP long shape: (1463, 4)
#
# Sample:
#                 country country_code  year  gdp_per_capita
# 0                 Aruba          ABW  2000    20681.023027
# 1           Afghanistan          AFG  2000      174.930991
# 2                Angola          AGO  2000      563.733796
# 3               Albania          ALB  2000     1160.420471
# 4               Andorra          AND  2000    21810.250381
# 5  United Arab Emirates          ARE  2000    29865.502347

# %%
# ============================================
# STEP 15: CREATE MASTER DATASET
# ============================================

# Start with depression prevalence as base
# Start with the depression dataset as our base table — everything else will be added to this
master = prev_depression.copy()

# Merge anxiety prevalence
# Add the anxiety rate column by matching rows where country AND year are the same
master = master.merge(
    prev_anxiety[['country', 'year', 'prevalence_rate']].rename(
        columns={'prevalence_rate': 'anxiety_rate'}),
    on=['country', 'year'], how='left'
)

# Rename depression rate
master = master.rename(columns={'prevalence_rate': 'depression_rate'})

# Drop cause column
# Delete the cause column because it's now redundant — every row is already depression data
master = master.drop(columns=['cause'])

print("After merging anxiety:", master.shape)
print(master.head(3))
# Out:
# After merging anxiety: (4488, 4)
#            country  year  depression_rate  anxiety_rate
# 0         Suriname  2000      5075.188955   6919.581675
# 1  Solomon Islands  2001      2962.021924   3615.766988
# 2        Guatemala  2000      5421.266100   5772.134496
