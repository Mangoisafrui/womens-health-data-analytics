# %%
# ============================================
# WOMEN'S MENTAL HEALTH PROJECT
# Notebook 3: Correlation Analysis
# Author: Christelle Denny
# Date: June 2026
# ============================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load master dataset
master = pd.read_csv("C:/Users/Dell/OneDrive/Desktop/Women's Mental Health/Clean Data/master_dataset.csv")

# Set visual style
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

print("✓ Libraries loaded!")
print("✓ Master dataset loaded!")
print(f"Shape: {master.shape}")
print(f"Columns: {list(master.columns)}")
# Out:
# ✓ Libraries loaded!
# ✓ Master dataset loaded!
# Shape: (1050, 11)
# Columns: ['country', 'year', 'depression_rate', 'anxiety_rate', 'Region', 'Income group', 'gii_score', 'gdp_per_capita', 'psychiatrists_per_100k', 'depression_daly', 'anxiety_daly']
